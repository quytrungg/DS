# %%
import pandas
from pandas import DataFrame
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# Gọi Dữ liệu
# ---

# %%
#%run GETAPI.ipynb  #for calling data

# %% [markdown]
# Xử lý dữ liệu đọc thêm tại file [Data exploration](Q_Data_Exploration.ipynb)

# %% [markdown]
# Đọc dữ liệu
# ---

# %%
symbols = pandas.read_csv('Data/symbols.csv')
data = pandas.read_csv('Data/data.csv')
f_data = pandas.read_csv('Data/token_price.csv')

try:
    symbols = symbols.drop(['Unnamed: 0'], axis=1)
except:
    pass
try:
    data = data.drop(['Unnamed: 0'], axis=1)
except:
    pass
try:
    f_data = f_data.drop(['Unnamed: 0'], axis=1)
except:
    pass
base_coin = ['BUSD','USDT'] # đồng tiền ổn định giá

# %% [markdown]
# ## Trả lời một sô câu hỏi

# %%
symbols[(symbols.symbol == 'BTCUSDT')|(symbols.symbol == 'ETHUSDT')][['baseAsset','quoteAsset']].unstack().nunique()
# Out:
# 3

# %% [markdown]
# ------

# %% [markdown]
# ### Xem sự liên quan giữa giá và số lượng giao dịch

# %%
f_data[['base','Open price','High price','Low price','Close price','Number of trades']].groupby('base').mean().corr()
# Out:
#                   Open price  High price  Low price  Close price  \
# Open price          1.000000    1.000000   1.000000     1.000000
# High price          1.000000    1.000000   0.999999     1.000000
# Low price           1.000000    0.999999   1.000000     1.000000
# Close price         1.000000    1.000000   1.000000     1.000000
# Number of trades    0.665169    0.665176   0.665132     0.665142
#
#                   Number of trades
# Open price                0.665169
# High price                0.665176
# Low price                 0.665132
# Close price               0.665142
# Number of trades          1.000000

# %% [markdown]
# Độ tương quan khá thấp, nên có thể thấy số lượng giao dịch không có ảnh hưởng nhiều đến giá của đồng coin

# %% [markdown]
# ---

# %% [markdown]
# ### Kiểm tra xem giá trị quy đổi giữa các token với nhau, có tuân theo giá trị thực không

# %%
head_name = data.columns

# %%
def GetPrice(sym):
    for i in base_coin:
        temp = f_data[(f_data.base == sym) & (f_data.quote == i)]
        if temp.shape[0] !=0:
            return temp.set_index('Kline open time')[head_name[4:8]]
    return 1

# %%
temp = data.set_index(["Symbol","Kline open time"]).drop(head_name[8:],axis=1)
temp # xep lai data phan theo tung loại dao dich
# Out:
#                          base quote  Open price  High price  Low price  \
# Symbol  Kline open time
# ETHBTC  1669395600000     ETH   BTC    0.072026    0.072222   0.072026
#         1669397400000     ETH   BTC    0.072222    0.072335   0.072117
#         1669399200000     ETH   BTC    0.072163    0.072263   0.072101
#         1669401000000     ETH   BTC    0.072188    0.072261   0.072161
#         1669402800000     ETH   BTC    0.072223    0.072479   0.072197
# ...                       ...   ...         ...         ...        ...
# BUSDRON 1670943600000    BUSD   RON    4.629000    4.630000   4.620000
#         1670945400000    BUSD   RON    4.620000    4.631000   4.620000
#         1670947200000    BUSD   RON    4.631000    4.631000   4.630000
#         1670949000000    BUSD   RON    4.630000    4.631000   4.630000
#         1670950800000    BUSD   RON    4.631000    4.631000   4.630000
#
#                          Close price
# Symbol  Kline open time
# ETHBTC  1669395600000       0.072222
#         1669397400000       0.072162
#         1669399200000       0.072189
#         1669401000000       0.072212
#         1669402800000       0.072375
# ...                              ...
# BUSDRON 1670943600000       4.621000
#         1670945400000       4.630000
#         1670947200000       4.631000
#         1670949000000       4.631000
#         1670950800000       4.631000
#
# [1229162 rows x 6 columns]

# %%
diff = []
for i in set(temp.index.get_level_values(0)):
    baseA  =  symbols[symbols.symbol==i].baseAsset.values[0]
    quoteA = symbols[symbols.symbol==i].quoteAsset.values[0]
    cal = GetPrice(baseA) / GetPrice(quoteA)
    try:
        gap = numpy.nanmean(cal - temp.loc[i][head_name[4:8]],axis=0) #differenct between price
        # % of gap to total
        gap /= numpy.mean(temp.loc[i][head_name[4:8]],axis=0)
        diff += [gap]        
    except:
        diff += [[0,0,0,0]]
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\TNT\Desktop\DickHead\main.ipynb Cell 18 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> baseA  =  symbols[symbols.symbol==i].baseAsset.values[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> quoteA = symbols[symbols.symbol==i].quoteAsset.values[0]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> cal = GetPrice(baseA) / GetPrice(quoteA)
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> try:
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a>     gap = numpy.nanmean(cal - temp.loc[i][head_name[4:8]],axis=0) #differenct between price
#
# c:\Users\TNT\Desktop\DickHead\main.ipynb Cell 18 in GetPrice(sym)
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> def GetPrice(sym):
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a>     for i in base_coin:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>         temp = f_data[(f_data.base == sym) & (f_data.quote == i)]
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>         if temp.shape[0] !=0:
#       <a href='vscode-notebook-cell:/c%3A/Users/TNT/Desktop/DickHead/main.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>             return temp.set_index('Kline open time')[head_name[4:8]]
#
# File c:\Users\TNT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File c:\Users\TNT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\TNT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# -> 5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\TNT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\ops\array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\TNT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\ops\array_ops.py:74, in comp_method_OBJECT_ARRAY(op, x, y)
#      72 else:
#      73     result = libops.scalar_compare(x.ravel(), y, op)
# ---> 74 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
numpy.mean(diff,axis = 0)
# Out:
# array([0.02731673, 0.02641888, 0.02802794, 0.02729723])

# %% [markdown]
# Sự chênh lệch nằm ở tầm 2-3% (dương) giá trị token, có thể nói khi trao đổi thông qua đồng tiền nền thì ta sẽ mất nhiều phí hơn là trao đổi trực tiếp giữa 2 token với nhau, nhưng đồng thời cũng cho thấy được là giá trị quy đổi các token có tuân theo giá trị thực của chúng
#
# ------

# %% [markdown]
# ### Xem sét 1 đồng tiền cụ thể (ETH) để xem giao dịch có làm ảnh hưởng đến giá trị không

# %%
#tong so luong giao dich co lien quan den dong ETH theo thoi gian
ETH_price_trade =pandas.concat( [GetPrice('ETH'), data[(data.base == 'ETH' )|(data.quote == 'ETH')].groupby("Kline open time").sum()[["Number of trades"]]],axis = 1)
ETH_price_trade.corr()["Number of trades"]
# Out:
# Open price         -0.020199
# High price          0.068455
# Low price          -0.059944
# Close price         0.017932
# Number of trades    1.000000
# Name: Number of trades, dtype: float64

# %% [markdown]
# Có thể thấy không có nhiều sự liên quan giữa số lượng giao dịch và giá đối với đồng tiền ETH này <br>
# xem xét biểu đồ dưới đây

# %%
fig, axs = plt.subplots(2, 2,figsize=(25, 10))
axs[0, 0].plot(ETH_price_trade["Number of trades"])
axs[0, 0].set_title('Number of trades')
axs[0, 1].plot(ETH_price_trade["Open price"])
axs[0, 1].set_title('Open price')
axs[1, 0].plot(ETH_price_trade["High price"])
axs[1, 0].set_title('High price')
axs[1, 1].plot(ETH_price_trade["Low price"])
axs[1, 1].set_title('Low price')
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# Tuy nhiên, nếu chúng ta để ý thì tại những mốc có lượng giao dịch vượt trội (mode), thì giá của đồng ETH này cũng biến động lớn ở thời điểm gần như tương tự, thế nên số lương giao dịch, đôi khi cũng phải ảnh được các cột mốc quan trọng trong biến động giá của token
# ____

# %% [markdown]
# ### câu 4

# %% [markdown]
# ## Model

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Theo như một số câu hỏi trước thì có rất ít loại đồng có ảnh hưởng đến nhau, nên trong model này ta chỉ huấn luyện trên 1 đồng để nhận xet thử

# %%
model_set = data[data.Symbol == 'ETHBTC'].sort_values('Kline open time')[['Open price','High price','Low price','Close price','Number of trades']]

model_set = StandardScaler().fit_transform(model_set)

# %%
train_X, train_y = model_set, model_set[5:,:4]
train_X.shape,train_y.shape
# Out:
# ((865, 5), (860, 4))

# %%
model = keras.Sequential()
model.add(layers.LSTM(
    units = 25,
    input_shape =(5,5)
))
model.add(layers.Dense(units = 4))
model.compile(
    loss='mean_squared_error',
    optimizer=keras.optimizers.Adam(0.001)
)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 25)                3100
#
#  dense_2 (Dense)             (None, 4)                 104
#
# =================================================================
# Total params: 3,204
# Trainable params: 3,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
full_n = train_y.shape[0]
n  =  int(train_y.shape[0]*0.7)

# %%
ds = keras.preprocessing.timeseries_dataset_from_array(train_X[:n],train_y[:n],sequence_length=5,batch_size=1) #train
d2 = keras.preprocessing.timeseries_dataset_from_array(train_X[n:],train_y[n:],sequence_length=5,batch_size=1) #test

# %%
test_x = numpy.array([i[0] for i in d2])
test_x.resize(( full_n - n, 5, 5))

# %%
model.fit(ds)
y_pred = model.predict(test_x)
y_pred.shape
# Out:
# 598/598 [==============================] - 6s 4ms/step - loss: 0.1537
# 9/9 [==============================] - 0s 3ms/step
# (258, 4)

# %%
k = 1
plt.figure(figsize=(20, 10))
plt.grid(which='major', axis='both', zorder=-0.5)
plt.plot( np.array(train_y)[:n,k],'b',label = 'train')
plt.plot(range(n,full_n),np.array(train_y)[n:,k],'g',label = 'y_true')
plt.plot(range(n,full_n), y_pred[:,k],'r',label = 'y_pred')
plt.legend()

# %%
[sklearn.metrics.r2_score( np.array(train_y)[n:,i],y_pred[:,i]) for i in range(4)]
# Out:
# [0.6429024846527189,
#  0.5266245805612102,
#  0.5160636719077022,
#  0.36992960254785057]

# %% [markdown]
# ---

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()
linear_model.fit( [ np.array(i[0]).flatten() for i in ds], [ np.array(i[1]).flatten() for i in ds] )
# Out:
# LinearRegression()

# %%
y_pred  = linear_model.predict( [ np.array(i[0]).flatten() for i in d2])
y_true = np.array([np.array(i[1]).flatten() for i in d2])

# %%
k = 3
plt.figure(figsize=(20, 10))
plt.grid(which='major', axis='both', zorder=-0.5)
plt.plot( np.array(train_y)[:n,k],'b',label = 'train')
plt.plot(range(n,full_n),(y_true)[:,k],'g',label = 'y_true')
plt.plot(range(n,full_n), y_pred[:,k],'r',label = 'y_pred')
plt.legend()

# %%
data
# Out:
#           Symbol  base quote  Kline open time  Open price  High price  \
# 0         ETHBTC   ETH   BTC    1669395600000    0.072026    0.072222
# 1         ETHBTC   ETH   BTC    1669397400000    0.072222    0.072335
# 2         ETHBTC   ETH   BTC    1669399200000    0.072163    0.072263
# 3         ETHBTC   ETH   BTC    1669401000000    0.072188    0.072261
# 4         ETHBTC   ETH   BTC    1669402800000    0.072223    0.072479
# ...          ...   ...   ...              ...         ...         ...
# 1229157  BUSDRON  BUSD   RON    1670943600000    4.629000    4.630000
# 1229158  BUSDRON  BUSD   RON    1670945400000    4.620000    4.631000
# 1229159  BUSDRON  BUSD   RON    1670947200000    4.631000    4.631000
# 1229160  BUSDRON  BUSD   RON    1670949000000    4.630000    4.631000
# 1229161  BUSDRON  BUSD   RON    1670950800000    4.631000    4.631000
#
#          Low price  Close price      Volume  Kline Close time  \
# 0         0.072026     0.072222   1342.1624     1669397399999
# 1         0.072117     0.072162   1185.9640     1669399199999
# 2         0.072101     0.072189    813.4793     1669400999999
# 3         0.072161     0.072212    936.2168     1669402799999
# 4         0.072197     0.072375   1115.5725     1669404599999
# ...            ...          ...         ...               ...
# 1229157   4.620000     4.621000   5984.0000     1670945399999
# 1229158   4.620000     4.630000   3618.0000     1670947199999
# 1229159   4.630000     4.631000   3254.0000     1670948999999
# 1229160   4.630000     4.631000  14415.0000     1670950799999
# 1229161   4.630000     4.631000   3875.0000     1670952599999
#
#          Quote asset volume  Number of trades  Taker buy base asset volume  \
# 0                 96.776126              2657                     794.6663
# 1                 85.640393              2727                     560.9044
# 2                 58.717779              1862                     359.8931
# 3                 67.599402              1816                     470.6928
# 4                 80.727099              3088                     593.4310
# ...                     ...               ...                          ...
# 1229157        27672.337000               108                    2086.0000
# 1229158        16734.982000                42                    1642.0000
# 1229159        15069.018000                33                    2998.0000
# 1229160        66749.027000                92                    7577.0000
# 1229161        17943.045000                52                    1795.0000
#
#          Taker buy quote asset volume  Unused field, ignore
# 0                           57.298344                     0
# 1                           40.508977                     0
# 2                           25.975732                     0
# 3                           33.988586                     0
# 4                           42.945939                     0
# ...                               ...                   ...
# 1229157                   9651.160000                     0
# 1229158                   7593.482000                     0
# 1229159                  13883.738000                     0
# 1229160                  35089.087000                     0
# 1229161                   8312.645000                     0
#
# [1229162 rows x 15 columns]

# %%
[sklearn.metrics.r2_score( np.array(y_true)[:,i],y_pred[:,i]) for i in range(5)]
# Out:
# [0.9999414948929016,
#  0.8734676318398551,
#  0.9103411549132344,
#  0.827581974209386,
#  -0.03827041212145743]

# %%
def r2_score_linear(symbol:str,plot = True,k=3,scaler = StandardScaler):
    set = data[data.Symbol == symbol].sort_values('Kline open time')[['Open price','High price','Low price','Close price','Number of trades']]
    if scaler != None:
        set = scaler().fit_transform(set)

    X, y = set, set[5:,:4]

    _full_n = y.shape[0]
    _n  = int(y.shape[0]*0.7)

    d_s1 = keras.preprocessing.timeseries_dataset_from_array(X[:_n],y[:_n],sequence_length=5,batch_size=1) #train
    d_s2 = keras.preprocessing.timeseries_dataset_from_array(X[_n:],y[_n:],sequence_length=5,batch_size=1) #test

    linear_ = LinearRegression()
    linear_.fit( [ np.array(i[0]).flatten() for i in d_s1], [ np.array(i[1]).flatten() for i in d_s1] )
    _pred  = linear_.predict( [ np.array(i[0]).flatten() for i in d_s2])
    _true = np.array([np.array(i[1]).flatten() for i in d_s2])

    if plot:
        plt.figure(figsize=(20, 10))
        plt.grid(which='major', axis='both', zorder=-1.0)
        plt.plot( np.array(y)[:_n,k],'b',label = 'train')
        plt.plot(range(_n,_full_n),(_true)[:,k],'g',label = 'y_true')
        plt.plot(range(_n,_full_n), _pred[:,k],'r',label = 'y_pred')
        plt.legend()

    print( np.mean(_pred - _true ,axis = 0) )
    return np.array([sklearn.metrics.r2_score( _true[:,i],_pred[:,i]) for i in range(4)])

# %%
r2_score_linear('BTCUSDT',k=0)
# Out:
# [-0.00015765 -0.00854214 -0.02071131 -0.02497725]
# array([0.99998509, 0.95133954, 0.98109645, 0.94771748])

# %% [markdown]
# Kết qua mô hình dự đoán với chỉ số khá cao, tuy nhiên việc áp dụng thực tế thì không hẳn là được, do dự đoán này sẽ phải dựa vào 5 mốc tgian trước đó, không phải hoàn toàn là sinh ra từ mô hình, nên việc giá có thể lên đỉnh, hoặc xuống đáy trong thời gian sau thì không được chắc chắn
