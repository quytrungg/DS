# %% [markdown]
# 20127001 - Hà Quốc Anh <br>
# 20127004 - Nguyễn Đức Bảo<br>
# 20127084 - Nguyễn Ngọc Bảo Trâm<br>
# 20127370 - Mai Quý Trung<br>
# 20127376 - Trần Nhật Trường<br>

# %% [markdown]
# # Import thư viện

# %%
import os
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
from sklearn import set_config
import seaborn as sns; sns.set()
import matplotlib.cm as cm
set_config(display='diagram')

# %% [markdown]
# # Đọc dữ liệu

# %%
path_to_data = './data'
path_track = os.path.join(path_to_data, '20210824_212829_tracks.tsv')
path_playlist = os.path.join(path_to_data, '20210824_212829_playlists.tsv')
path_audio =  os.path.join(path_to_data, '20210824_212829_audios.tsv')
path_artist =  os.path.join(path_to_data, '20210824_212829_artists.tsv')

# %%
pd_track = pd.read_csv(path_track, sep='\t')
pd_audio = pd.read_csv(path_audio, sep='\t')
pd_playlist = pd.read_csv(path_playlist, sep='\t')
pd_artist = pd.read_csv(path_artist, sep='\t')

# %%
pd_audio
# Out:
#                            id  danceability  energy  key  loudness  mode  \
# 0      5HCyWlXZPP0y6Gqq8TgA20         0.591   0.764    1    -5.484     1
# 1      27NovPIUIRrOZoCHxABJwK         0.736   0.704    3    -7.409     0
# 2      3Vi5XqYrmQgOYBajMWSvCi         0.664   0.609    1    -6.509     1
# 3      6PQ88X9TkUIAUIZJHW2upE         0.808   0.897   11    -3.712     0
# 4      3Wrjm47oTz2sjIgck11l5e         0.714   0.800   11    -4.808     0
# ...                       ...           ...     ...  ...       ...   ...
# 69866  3Zuf70897YkrVRAsrBMMSF         0.751   0.753    0    -8.198     1
# 69867  1MDoll6jK4rrk2BcFRP5i7         0.471   0.431    5    -6.129     0
# 69868  7DqTaelFf846rl1CHmyfOW         0.506   0.433    2   -14.183     0
# 69869  0ygTmpa6uSotkBkTiwcMZ4         0.493   0.590    0    -5.814     0
# 69870  3NNqqioprPCnYcVtDn3wvS         0.836   0.499    1    -9.882     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
pd_audio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69871 entries, 0 to 69870
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                69871 non-null  object
#  1   danceability      69871 non-null  float64
#  2   energy            69871 non-null  float64
#  3   key               69871 non-null  int64
#  4   loudness          69871 non-null  float64
#  5   mode              69871 non-null  int64
#  6   speechiness       69871 non-null  float64
#  7   acousticness      69871 non-null  float64
#  8   instrumentalness  69871 non-null  float64
#  9   liveness          69871 non-null  float64
#  10  valence           69871 non-null  float64
#  11  tempo             69871 non-null  float64
#  12  time_signature    69871 non-null  int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 6.9+ MB

# %%
pd_track
# Out:
#                   playlist_id                track_id  \
# 0      37i9dQZF1DXcBWIGoYBM5M  5HCyWlXZPP0y6Gqq8TgA20
# 1      37i9dQZF1DXcBWIGoYBM5M  27NovPIUIRrOZoCHxABJwK
# 2      37i9dQZF1DXcBWIGoYBM5M  3Vi5XqYrmQgOYBajMWSvCi
# 3      37i9dQZF1DXcBWIGoYBM5M  6PQ88X9TkUIAUIZJHW2upE
# 4      37i9dQZF1DXcBWIGoYBM5M  3Wrjm47oTz2sjIgck11l5e
# ...                       ...                     ...
# 88814  4lgseztVwmKQ8MNETPVIny  5kqIPrATaCc2LqxVWzQGbk
# 88815  4lgseztVwmKQ8MNETPVIny  3FCto7hnn1shUyZL42YgfO
# 88816  4lgseztVwmKQ8MNETPVIny  3XVBdLihbNbxUwZosxcGuJ
# 88817  4lgseztVwmKQ8MNETPVIny  6QPKYGnAW9QozVz2dSWqRg
# 88818  4lgseztVwmKQ8MNETPVIny  1VdZ0vKfR5jneCmWIUAMxK
#
#                               track_name  track_duration  \
# 0              STAY (with Justin Bieber)          141805
# 1      INDUSTRY BABY (feat. Jack Harlow)          212000
# 2                           Need To Know          210560
# 3                             Bad Habits          231041
# ...

# %%
pd_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88819 entries, 0 to 88818
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   playlist_id     88819 non-null  object
#  1   track_id        88819 non-null  object
#  2   track_name      88812 non-null  object
#  3   track_duration  88819 non-null  int64
#  4   artist_ids      88819 non-null  object
#  5   artist_names    88819 non-null  object
#  6   album_id        88819 non-null  object
#  7   album_name      88811 non-null  object
#  8   popularity      88819 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 6.1+ MB

# %%
pd_playlist
# Out:
#                  playlist_id            playlist_name  \
# 0     37i9dQZF1DXcBWIGoYBM5M         Today's Top Hits
# 1     37i9dQZF1DX0XUsuxWHRQd                RapCaviar
# 2     37i9dQZF1DX1lVhptIYRda              Hot Country
# 3     37i9dQZF1DX10zKzsJ2jva            ¡Viva Latino!
# 4     37i9dQZF1DX4JAvHpjipBk         New Music Friday
# ...                      ...                      ...
# 1390  37i9dQZF1DX3WvGXE8FqYX             Women of Pop
# 1391  5ji4GZJpll6twskFvKxiHx                     dw-c
# 1392  40VxbK9NqccdUDUpiUXmbp                     dw_g
# 1393  0RTz1jFo5BXGPfI8eVf8sj         Top Shower Songs
# 1394  4lgseztVwmKQ8MNETPVIny  foodora dinner playlist
#
#                                    playlist_description  playlist_num_tracks  \
# 0                 Doja Cat is on top of the Hottest 50!                   50
# 1     New music from Young Thug, Trippie Redd, Rod W...                   50
# 2     Today's top country hits of the week, worldwid...                   53
# ...

# %%
pd_playlist.fillna('None')
# Out:
#                  playlist_id            playlist_name  \
# 0     37i9dQZF1DXcBWIGoYBM5M         Today's Top Hits
# 1     37i9dQZF1DX0XUsuxWHRQd                RapCaviar
# 2     37i9dQZF1DX1lVhptIYRda              Hot Country
# 3     37i9dQZF1DX10zKzsJ2jva            ¡Viva Latino!
# 4     37i9dQZF1DX4JAvHpjipBk         New Music Friday
# ...                      ...                      ...
# 1390  37i9dQZF1DX3WvGXE8FqYX             Women of Pop
# 1391  5ji4GZJpll6twskFvKxiHx                     dw-c
# 1392  40VxbK9NqccdUDUpiUXmbp                     dw_g
# 1393  0RTz1jFo5BXGPfI8eVf8sj         Top Shower Songs
# 1394  4lgseztVwmKQ8MNETPVIny  foodora dinner playlist
#
#                                    playlist_description  playlist_num_tracks  \
# 0                 Doja Cat is on top of the Hottest 50!                   50
# 1     New music from Young Thug, Trippie Redd, Rod W...                   50
# 2     Today's top country hits of the week, worldwid...                   53
# ...

# %%
pd_playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1395 entries, 0 to 1394
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   playlist_id             1395 non-null   object
#  1   playlist_name           1395 non-null   object
#  2   playlist_description    1239 non-null   object
#  3   playlist_num_tracks     1395 non-null   int64
#  4   playlist_num_followers  1395 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 54.6+ KB

# %%
pd_artist
# Out:
#                            id                 name  followers  popularity  \
# 0      2xgAJkalFHfceCNGETOkyM                  GRX      76585          43
# 1      6enyYil5r9snkIazgAX5DG         Jo Ann Kelly        998          20
# 2      40oYPr305MsT2lsiXr9fX9    The Boomtown Rats     116274          54
# 3      3i8iJVU0mtgzbZsuF1AoJ3             sad alex      23548          52
# 4      5oFkj1qSlyBUmV5d6Edgtq                 Cozz     146831          57
# ...                       ...                  ...        ...         ...
# 34649  1tY6Z4NEPI3xHhVA8VU9Jl   Vishwa Mohan Bhatt      23094          30
# 34650  7lPv78tlT005m22dYvSdNg      Lindsey Leblanc         52          32
# 34651  6iXZPP5qLB2dtIQ4WuNk9M  Thelonious Coltrane       4359          44
# 34652  7s9LTAKRwkBQ0CqWlbE254                Frase       2245          36
# 34653  5uuqghaOBgtv92jDyDveQl      Frances Forever      77788          61
#
#                                                   genres
# ...

# %%
pd_artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34654 entries, 0 to 34653
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          34654 non-null  object
#  1   name        34654 non-null  object
#  2   followers   34654 non-null  int64
#  3   popularity  34654 non-null  int64
#  4   genres      34654 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# # Mô tả dữ liệu
#
# ## Ý nghĩa mỗi cột

# %% [markdown]
# ### Track

# %%
pd.read_csv('./data_description/des_tracks.csv')
# Out:
#       column name  data type  \
# 0     playlist_id     string
# 1        track_id     string
# 2      track_name     string
# 3  track_duration        int
# 4      artist_ids       list
# 5    artist_names       list
# 6        album_id     string
# 7      album_name     string
# 8      popularity       int
#
#                                              meaning  \
# 0                     The Spotify ID of the playlist
# 1                       The Spotify ID for the track
# 2                              The name of the track
# 3          The duration of the track in milliseconds
# 4   A comma-separated list for the Spotify ID of ...
# 5             A comma-separated list of artists name
# 6   A comma-separated list of the Spotify IDs for...
# 7                                 Name of the album
# 8  The popularity of the track. The value will be...
#
#                                             example
# 0                            37i9dQZF1DXcBWIGoYBM5M
# ...

# %% [markdown]
# ### Playlist

# %%
pd.read_csv('./data_description/des_playlist.csv')
# Out:
#               column name  data type                             meaning  \
# 0             playlist_id     string      The Spotify ID of the playlist
# 1           playlist_name   'string'                The name of playlist
# 2    playlist_description   'string'         The description of playlist
# 3     playlist_num_tracks      'int'   Number of tracks in that playlist
# 4  playlist_num_followers      'int'    Number of this playlist follower
#
#                                   example
# 0                  37i9dQZF1DXcBWIGoYBM5M
# 1                        Today's Top Hits
# 2   Doja Cat is on top of the Hottest 50!
# 3                                      50
# 4                                29379379

# %% [markdown]
# **Câu 1:** Nhận xét về phân phối của các playlist dựa vào số lượng bài hát và số lượng người theo dõi

# %%
playlist_distribution_data = pd_playlist[['playlist_num_tracks', 'playlist_num_followers']].describe().iloc[1:, :].astype('int64')

print(playlist_distribution_data)
plt.figure(figsize=(30, 30))
fig,ax = plt.subplots(1, 2)
ax[0].bar( playlist_distribution_data.index, playlist_distribution_data['playlist_num_tracks'],color = 'b')
ax[1].bar( playlist_distribution_data.index, playlist_distribution_data['playlist_num_followers'],color = 'g')
# Out:
#       playlist_num_tracks  playlist_num_followers
# mean                   77                  581556
# std                    62                 1452507
# min                     0                       7
# 25%                    45                    6040
# 50%                    58                  141065
# 75%                   100                  565401
# max                   851                29379379
# <BarContainer object of 7 artists>

# %% [markdown]
# - Nhìn chung phân phối không đồng đều, khi có tồn tại một vài playlist có lượng bài hát hoặc số lượng người theo dõi rất nhiều, điều này sẽ phần nào ảnh hưởng đến thuật toán khi sample ra các playlist được nhận định như là outlier này
# - Xét sự phân phối của các playlist dựa vào số lượng bài hát và số lượng người theo dõi, cả 2 yếu tố dều có giá trị lớn nhất vượt trội rất nhiều so với giá trị trung bình và nhỏ nhất.

# %% [markdown]
# ### Artist

# %%
pd.read_csv('./data_description/des_artist.csv')
# Out:
#   column name  data type                                            meaning  \
# 0          id     string                           The Spotify ID of artist
# 1        name     string                                 Name of the artist
# 2   followers        int                     Number of that artist follower
# 3  popularity        int  The popularity of the artist. The value will b...
# 4      genres       list   A comma seperated list of genres of that arti...
#
#                                     example
# 0                    1uNFoZAHBGtllmzznpCI3s
# 1                             Justin Bieber
# 2                                  48927405
# 3                                        98
# 4  ['canadian pop', 'pop', 'post-teen pop']

# %% [markdown]
# **Câu 2 :** Ca sĩ sẽ chọn hát dòng nhạc nào phổ biến nhất

# %%
data_2 = pd.DataFrame(pd_artist['genres'].str.split(r'\]|,|\[').explode().value_counts()).drop(['']).nlargest(n=10, columns='genres')

data = data_2.to_numpy().reshape(-1)
labels = [i for i, _ in data_2.iterrows()]

colors = sns.color_palette('pastel')[0:10]

plt.pie(data, labels = labels, colors = colors, autopct='%.1f%%')
plt.show()

# %% [markdown]
# - Chúng ta thấy phần lớn các ca sĩ chọn cho mình dòng nhạc rock, pop, rap và các biến thể của chúng.
# - Hơn 50% số lượng bài hát thuộc thể loại pop, rock và các biến thể của nó.
# - Rap và pop rap chiếm lần lượt 9.4% và 9%, điều đó cho thấy thể loại nhạc rap hiện nay đang khá thịnh hành.
# - Ngoài ra có loại nhạc 'electro house' cũng lọt vào top với 8.9%

# %% [markdown]
# ## Cách tổ chức
#
# + Dataframe `pd_track` mô tả thông tin về một playlist sẽ chứa các track nào, một `playlist_id` sẽ có thể có nhiều `track_id`. Ngoài ra còn một số thông tin khác ở đây chẳng hạn như độ phổ biến, thời lượng track,...
# + Sử dụng các `track_id` để truy xuất các thông tin đặc trưng về âm thanh tại dataframe `pd_audio`. Tại Dataframe này, các đặc trưng âm học sẽ được biểu diễn.

# %% [markdown]
# `pd_full` sẽ là một Dataframe tổng hợp tất cả thông tin bao gồm cả các đặc trưng về audio

# %%
pd_track = pd.merge(pd_track, pd_audio, left_on = 'track_id', right_on = 'id')
pd_track

pd_full = pd.merge(pd_track, pd_playlist, left_on = 'playlist_id', right_on = 'playlist_id')
pd.set_option('display.max_columns', None)
pd_full
# Out:
#                   playlist_id                track_id  \
# 0      37i9dQZF1DXcBWIGoYBM5M  5HCyWlXZPP0y6Gqq8TgA20
# 1      37i9dQZF1DXcBWIGoYBM5M  27NovPIUIRrOZoCHxABJwK
# 2      37i9dQZF1DXcBWIGoYBM5M  3Vi5XqYrmQgOYBajMWSvCi
# 3      37i9dQZF1DXcBWIGoYBM5M  6PQ88X9TkUIAUIZJHW2upE
# 4      37i9dQZF1DXcBWIGoYBM5M  3Wrjm47oTz2sjIgck11l5e
# ...                       ...                     ...
# 88618  3yUO32lGCEnAfFGORSEsy4  6jKNYORXeWGGGiSkj1sBZu
# 88619  3yUO32lGCEnAfFGORSEsy4  5DycXVa4e82E6k9M15Nf51
# 88620  3yUO32lGCEnAfFGORSEsy4  41gA2hLHRJW4bC40lm2X7R
# 88621  3yUO32lGCEnAfFGORSEsy4  0K22864F8jwAymy5JsopR9
# 88622  3yUO32lGCEnAfFGORSEsy4  0IqAVLRSSNDybTiD4NXMWo
#
#                               track_name  track_duration  \
# 0              STAY (with Justin Bieber)          141805
# 1      INDUSTRY BABY (feat. Jack Harlow)          212000
# 2                           Need To Know          210560
# 3                             Bad Habits          231041
# ...

# %%
pd_full = pd_full.drop('playlist_name', axis = 1)
pd_full = pd_full.drop('playlist_description', axis = 1)
pd_full = pd_full.drop('id', axis = 1)

# %%
pd_full
# Out:
#                   playlist_id                track_id  \
# 0      37i9dQZF1DXcBWIGoYBM5M  5HCyWlXZPP0y6Gqq8TgA20
# 1      37i9dQZF1DXcBWIGoYBM5M  27NovPIUIRrOZoCHxABJwK
# 2      37i9dQZF1DXcBWIGoYBM5M  3Vi5XqYrmQgOYBajMWSvCi
# 3      37i9dQZF1DXcBWIGoYBM5M  6PQ88X9TkUIAUIZJHW2upE
# 4      37i9dQZF1DXcBWIGoYBM5M  3Wrjm47oTz2sjIgck11l5e
# ...                       ...                     ...
# 88618  3yUO32lGCEnAfFGORSEsy4  6jKNYORXeWGGGiSkj1sBZu
# 88619  3yUO32lGCEnAfFGORSEsy4  5DycXVa4e82E6k9M15Nf51
# 88620  3yUO32lGCEnAfFGORSEsy4  41gA2hLHRJW4bC40lm2X7R
# 88621  3yUO32lGCEnAfFGORSEsy4  0K22864F8jwAymy5JsopR9
# 88622  3yUO32lGCEnAfFGORSEsy4  0IqAVLRSSNDybTiD4NXMWo
#
#                               track_name  track_duration  \
# 0              STAY (with Justin Bieber)          141805
# 1      INDUSTRY BABY (feat. Jack Harlow)          212000
# 2                           Need To Know          210560
# 3                             Bad Habits          231041
# ...

# %%
pd_full = pd_full.drop_duplicates()
pd_full = pd_full.fillna('None')
pd_full
# Out:
#                   playlist_id                track_id  \
# 0      37i9dQZF1DXcBWIGoYBM5M  5HCyWlXZPP0y6Gqq8TgA20
# 1      37i9dQZF1DXcBWIGoYBM5M  27NovPIUIRrOZoCHxABJwK
# 2      37i9dQZF1DXcBWIGoYBM5M  3Vi5XqYrmQgOYBajMWSvCi
# 3      37i9dQZF1DXcBWIGoYBM5M  6PQ88X9TkUIAUIZJHW2upE
# 4      37i9dQZF1DXcBWIGoYBM5M  3Wrjm47oTz2sjIgck11l5e
# ...                       ...                     ...
# 88618  3yUO32lGCEnAfFGORSEsy4  6jKNYORXeWGGGiSkj1sBZu
# 88619  3yUO32lGCEnAfFGORSEsy4  5DycXVa4e82E6k9M15Nf51
# 88620  3yUO32lGCEnAfFGORSEsy4  41gA2hLHRJW4bC40lm2X7R
# 88621  3yUO32lGCEnAfFGORSEsy4  0K22864F8jwAymy5JsopR9
# 88622  3yUO32lGCEnAfFGORSEsy4  0IqAVLRSSNDybTiD4NXMWo
#
#                               track_name  track_duration  \
# 0              STAY (with Justin Bieber)          141805
# 1      INDUSTRY BABY (feat. Jack Harlow)          212000
# 2                           Need To Know          210560
# 3                             Bad Habits          231041
# ...

# %% [markdown]
# **Câu 3 :** Playlist nào có số lượng người theo dõi là nhiều nhất

# %%
pd_playlist[['playlist_name','playlist_num_followers']].nlargest(10,'playlist_num_followers')
# Out:
#                 playlist_name  playlist_num_followers
# 0            Today's Top Hits                29379379
# 626           Top 50 - Global                16264194
# 1                   RapCaviar                14030878
# 3               ¡Viva Latino!                11218997
# 799  Songs to Sing in the Car                 9889452
# 12                All Out 00s                 9529670
# 7               Rock Classics                 9296917
# 14                All Out 80s                 8818602
# 13                All Out 90s                 6805571
# 707              Mood Booster                 6799190

# %%
pd_playlist[['playlist_name','playlist_num_followers']].set_index('playlist_name').nlargest(10,'playlist_num_followers').plot.barh(figsize= (10,10))
# Out:
# <AxesSubplot:ylabel='playlist_name'>

# %% [markdown]
# Today's Top Hits có số lượng vượt trội hơn hẳn so với các playlist còn lại (gần 30 triệu follower và gần gấp đôi so với top 2) <br> điều đó cho thấy playlist có nhiều bài hát phổ biến với phần lớn lượng người dùng hiện tại

# %% [markdown]
# **Câu 4 :** Playlist nào có số lượng bài hát là nhiều nhất

# %%
temp2_playlist = pd_playlist.copy()

temp2_playlist = temp2_playlist.drop('playlist_description', axis = 1)
temp2_playlist = temp2_playlist.drop('playlist_num_followers', axis = 1)
top10_tracks = temp2_playlist.nlargest(n = 10, columns=['playlist_num_tracks'])
top10_tracks.set_index('playlist_name').plot.barh(figsize = (10,10))
# Out:
# <AxesSubplot:ylabel='playlist_name'>

# %% [markdown]
# Playlist Sonisphere đứng top 1 về số lượng bài hát nhiều nhất (851 bài hát), con số này cao hơn hẳn (gấp từ 2 đến 3 lần) so với các playlist từ top 4 trở xuống. <br>
# Tuy nhiên, xét trong top 10 này, thì playlist đứng đầu về số lượng bài hát lại có số followers thấp nhất (21 followers). Trong khi đó playlist có ít bài hát nhất lại có số followers nằm top đầu (1201021 followers) <br>
# Vì vậy, ta không thể kết luận rằng playlist nào có càng nhiều bài hát thì càng có nhiều followers.

# %% [markdown]
# **Câu 5 :** Nhận xét về mức độ tương quan của các thông tin audio với nhau

# %%
pd_audio.corr(method='spearman')
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000  0.161258  0.024132  0.222373 -0.072061
# energy                0.161258  1.000000  0.023232  0.828651 -0.066645
# key                   0.024132  0.023232  1.000000  0.016213 -0.145822
# loudness              0.222373  0.828651  0.016213  1.000000 -0.043052
# mode                 -0.072061 -0.066645 -0.145822 -0.043052  1.000000
# speechiness           0.224729  0.138346  0.036404  0.035088 -0.106451
# acousticness         -0.182463 -0.784392 -0.020993 -0.692730  0.071842
# instrumentalness     -0.299920 -0.167804 -0.008651 -0.341242 -0.043868
# liveness             -0.046153  0.158791  0.007087  0.086764 -0.005414
# valence               0.522456  0.396673  0.024161  0.366289 -0.000361
# tempo                -0.002260  0.264611 -0.003600  0.241143  0.000926
# time_signature        0.158018  0.225875 -0.005959  0.221428 -0.025584
#
# ...

# %% [markdown]
# Các thông tin của audio đa số có độ tương quan (gây ảnh hưởng đến nhau) với nhau khá thấp <br>
# chỉ có 3 cặp thông tin có gây ảnh hưởng đến nhau ở mức độ chấp nhận được, với chỉ số nằm ngoài khoảng [-0.6; 0.6] <br>
# với loudness ảnh hưởng đến energy (possitve) <br>
# với acousticness ảnh hưởng đến energy và loudness (negative)

# %% [markdown]
# **Câu 6 :** Các bài hát sẽ có mức độ phổ biến tương quan như thế nào với các đặc trưng audio

# %%
cols = pd_audio.columns.values.tolist() + ['popularity']
cols.remove('id')

# %%
pd_full[cols].corr(method='spearman')['popularity']
# Out:
# danceability        0.143618
# energy              0.157736
# key                 0.004261
# loudness            0.235342
# mode               -0.015014
# speechiness        -0.035578
# acousticness       -0.147607
# instrumentalness   -0.118566
# liveness           -0.056976
# valence             0.084447
# tempo               0.040616
# time_signature      0.090332
# popularity          1.000000
# Name: popularity, dtype: float64

# %% [markdown]
# với từng đặc trưng riêng lẻ, thì chúng không ảnh hưởng lớn đến độ phổ biến của bài hát

# %% [markdown]
# **Câu 7:** Nhóm nhạc nào có tham gia nhiều track nhất

# %%
data_7 = pd.DataFrame(pd_track['artist_names'].str.split(r'\]|,|\[').explode().value_counts()).drop(['']).nlargest(n=10, columns='artist_names')
data = data_7.to_numpy().reshape(-1)
labels = [i for i, _ in data_7.iterrows()]

colors = sns.color_palette('pastel')[0:10]

plt.pie(data, labels = labels, colors = colors, autopct='%.1f%%')
plt.show()

# %% [markdown]
# Số lượng bài hát tham gia bởi nhóm The Beatles vượt trội so với số liệu của hầu hết các nhóm khác trong top 10 (hơn 400 bài so với từ 150 đến gần 300 bài). <br>
# Hơn 1 nửa nhóm nhạc trong danh sách (7 nhóm) có số lượng bài hát gần như nhau (khoảng 160 bài).<br>
# Ed Sheeran và Penton Overseas tham gia hơn 250 bài là 2 nhóm đáng lưu ý.
